# %% [markdown]
# <a href="https://colab.research.google.com/github/lalitha-sahitya/Molecular-Data-Machine-Learning/blob/main/Molecular_Data_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
# !pip install opendatasets

# %%
import opendatasets as od
od.download('https://www.kaggle.com/competitions/molecular-machine-learning/data')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: sahityapalacharla
# Your Kaggle Key: ··········
# Extracting archive ./molecular-machine-learning/molecular-machine-learning.zip to ./molecular-machine-learning

# %%
os.listdir('molecular-machine-learning')
# Out:
# ['sample_submission.csv', 'train.csv', 'test.csv']

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/molecular-machine-learning/train.csv')
data.head()
# Out:
#    Batch_ID     T80                                             Smiles  \
# 0  Train-01  103.86             CCCCCCCCCCCCc1ccsc1-c1ccc(-c2cccs2)cc1
# 1  Train-02  101.13                        CCCCCCCCCCCCc1ccsc1-c1cccs1
# 2  Train-03   78.30  CN1CCN(S(=O)(=O)c2ccc(-c3ccc(-c4cccs4)cc3)cc2)CC1
# 3  Train-04   71.88     O=C1c2ccccc2C(=O)c2cc(-c3ccc(-c4cccs4)s3)ccc21
# 4  Train-05   68.37  CC(C)(C)OC(=O)n1ccc2ccc(-c3ccc(-c4ccc(-c5cccs5...
#
#       Mass  HAcceptors  HDonors    LogP  Asphericity        Rg   TPSA  ...  \
# 0  410.692           2        0  9.6070     0.301361  5.187321   0.00  ...
# 1  334.594           2        0  7.9400     0.367472  4.141425   0.00  ...
# 2  398.553           4        0  4.0182     0.799589  5.368024  40.62  ...
# 3  372.470           4        0  5.9190     0.793825  4.948903  34.14  ...
# 4  457.620           5        0  8.5485     0.671148  5.994751  31.23  ...
#
#     SDOS4.5   SDOS4.6   SDOS4.7   SDOS4.8   SDOS4.9   SDOS5.0   SDOS5.1  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Columns: 146 entries, Batch_ID to SDOS5.4
# dtypes: float64(138), int64(6), object(2)
# memory usage: 48.0+ KB

# %%
data.Batch_ID.nunique()
# Out:
# 42

# %%
len(data)
# Out:
# 42

# %%
data.Smiles.nunique()
# Out:
# 42

# %%
data=data.drop(['Batch_ID','Smiles'],axis=1)
data.head()
# Out:
#       T80     Mass  HAcceptors  HDonors    LogP  Asphericity        Rg   TPSA  \
# 0  103.86  410.692           2        0  9.6070     0.301361  5.187321   0.00
# 1  101.13  334.594           2        0  7.9400     0.367472  4.141425   0.00
# 2   78.30  398.553           4        0  4.0182     0.799589  5.368024  40.62
# 3   71.88  372.470           4        0  5.9190     0.793825  4.948903  34.14
# 4   68.37  457.620           5        0  8.5485     0.671148  5.994751  31.23
#
#    RingCount  NumRotatableBonds  ...   SDOS4.5   SDOS4.6   SDOS4.7   SDOS4.8  \
# 0          3                 13  ...  1.717761  1.970186  1.760071  1.224983
# 1          2                 12  ...  0.012396  0.046031  0.133124  0.299840
# 2          4                  4  ...  2.421162  2.703267  2.352276  1.595867
# 3          5                  2  ...  0.886320  0.579059  0.345148  0.246564
# 4          5                  3  ...  0.487723  0.245764  0.249019  0.363222
#
# ...

# %%
x=data.drop('T80',axis=1)
y=data['T80']

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Columns: 143 entries, Mass to SDOS5.4
# dtypes: float64(137), int64(6)
# memory usage: 47.1 KB

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras import layers
from keras.layers import Dense,Input

# %%
model=Sequential([
    layers.Input(shape=(x_train.shape[1],)),
    layers.Dense(128,activation='relu'),
    layers.Dense(64,activation='relu'),
    layers.Dense(1)
])
model.compile(optimizer='adam',loss='mse',metrics=['mae'])

# %%
history=model.fit(x_train,y_train,epochs=100,validation_data=(x_test,y_test))
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 242ms/step - loss: 1211.9962 - mae: 22.4855 - val_loss: 924.2872 - val_mae: 27.3065
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1308.3180 - mae: 30.9886 - val_loss: 1206.9285 - val_mae: 31.2080
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 1503.5425 - mae: 34.2286 - val_loss: 708.0916 - val_mae: 23.6742
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1099.8110 - mae: 27.5287 - val_loss: 492.0675 - val_mae: 16.7017
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 955.7318 - mae: 21.0336 - val_loss: 519.6804 - val_mae: 13.4306
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 1026.4236 - mae: 18.6775 - val_loss: 571.1330 - val_mae: 13.8031
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 1085.2384 - mae: 19.1567 - val_loss: 524.0020 - val_mae: 13.0889
# Epoch 8/100
# ...

# %%
preds=model.predict(x_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step

# %%
preds
# Out:
# array([[28.723637],
#        [34.23623 ],
#        [34.62216 ],
#        [34.31468 ],
#        [41.5942  ],
#        [ 8.741434],
#        [24.77919 ],
#        [23.711658],
#        [30.831316]], dtype=float32)

# %%
test=pd.read_csv('/content/molecular-machine-learning/test.csv')
test.head()
# Out:
#   Batch_ID  T80                                           Smiles     Mass  \
# 0  Test-01  NaN                COC(=O)c3ccc(c2ccc(c1ccco1)cc2)s3  284.336
# 1  Test-02  NaN  CCCCCCc2c(CCCCCC)c(c1cccs1)sc2c3ccc(C(=O)OC)cc3  468.728
# 2  Test-03  NaN           COC(=O)c3ccc(c2ccc(c1cccc(OC)c1)cc2)s3  324.401
# 3  Test-04  NaN  CCCCCCc3csc(c2ccc(c1ccc(C(=O)OC)s1)cc2)c3CCCCCC  468.728
# 4  Test-05  NaN      CCCCCCc1ccsc1c3cc(CCCCCC)c(c2sccc2CCCCCC)s3  500.883
#
#    HAcceptors  HDonors     LogP  Asphericity        Rg   TPSA  ...   SDOS4.5  \
# 0           4        0   4.4617     0.796737  4.323524  39.44  ...  0.709932
# 1           4        0   9.1758     0.268870  5.019005  26.30  ...  1.913133
# 2           4        0   4.8773     0.846029  4.976660  35.53  ...  2.302484
# 3           4        0   9.1758     0.654627  5.609674  26.30  ...  1.861847
# 4           3        0  11.5735     0.406478  5.526453   0.00  ...  0.432056
#
# ...

# %%
test_data=test.drop(['Batch_ID','Smiles'],axis=1)
test_data.head()
# Out:
#    T80     Mass  HAcceptors  HDonors     LogP  Asphericity        Rg   TPSA  \
# 0  NaN  284.336           4        0   4.4617     0.796737  4.323524  39.44
# 1  NaN  468.728           4        0   9.1758     0.268870  5.019005  26.30
# 2  NaN  324.401           4        0   4.8773     0.846029  4.976660  35.53
# 3  NaN  468.728           4        0   9.1758     0.654627  5.609674  26.30
# 4  NaN  500.883           3        0  11.5735     0.406478  5.526453   0.00
#
#    RingCount  NumRotatableBonds  ...   SDOS4.5   SDOS4.6   SDOS4.7   SDOS4.8  \
# 0          3                  4  ...  0.709932  0.266678  0.078569  0.020244
# 1          3                 16  ...  1.913133  1.823127  1.356344  0.797689
# 2          3                  6  ...  2.302484  1.460937  0.729424  0.299914
# 3          3                 16  ...  1.861847  1.032900  0.447376  0.154937
# 4          3                 20  ...  0.432056  0.166929  0.051487  0.016869
#
# ...

# %%
test_x=test_data.drop('T80',axis=1)
test_y=test_data['T80']

# %%
pred=model.predict(test_x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %%
pred
# Out:
# array([[41.632973],
#        [41.885727],
#        [42.323563],
#        [42.16223 ],
#        [40.770515],
#        [45.328182],
#        [42.70768 ],
#        [41.377823],
#        [41.817825]], dtype=float32)

# %%
sub=pd.read_csv('/content/molecular-machine-learning/sample_submission.csv')
sub.head()
# Out:
#   Batch_ID  T80
# 0  Test-01  1.5
# 1  Test-02  2.5
# 2  Test-03  3.5
# 3  Test-04  4.5
# 4  Test-05  5.5

# %%
sub['T80']=pred

# %%
sub
# Out:
#   Batch_ID        T80
# 0  Test-01  41.632973
# 1  Test-02  41.885727
# 2  Test-03  42.323563
# 3  Test-04  42.162231
# 4  Test-05  40.770515
# 5  Test-06  45.328182
# 6  Test-07  42.707680
# 7  Test-08  41.377823
# 8  Test-09  41.817825

# %%
sub.to_csv('submission.csv',index=False)
